# %% [markdown]
#                                                                   Sample Project
# Pandas:
#     Pandas is a python library used for working with data sets.
#     It has functions for analyzin, cleaning, exploring, and manipulating data.
# Matplotlib:
#     It is a plotting library for the python Programming language and its numerical mathematics extension NumPy.
#     It is a comprehensive library for creating static, animated, and Interactive visualizations in python.
# Seaborn:
#     Seaborn is a Python data visualization library based on matplotlib.
#     It provides a high level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# 1.Working with Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("movies.csv")
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df.tail(3)
# Out:
#                         title   industry  release_year  imdb_rating  \
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
df.shape
# Out:
# (37, 10)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.imdb_rating)
# Out:
# pandas.core.series.Series

# %%
df.imdb_rating.min(),df.imdb_rating.max(), df.imdb_rating.mean()
# Out:
# (1.9, 9.3, 7.919444444444445)

# %%
df.describe().T
# Out:
#               count         mean           std     min     25%     50%  \
# release_year   37.0  2007.027027     17.657995  1946.0  2001.0  2014.0
# imdb_rating    36.0     7.919444      1.204947     1.9     7.8     8.1
# budget         37.0  2084.975135  11477.487145     1.0    15.5   165.0
# revenue        37.0  4117.135135  16372.462682     3.1   263.1   701.8
#
#                  75%       max
# release_year  2018.0    2022.0
# imdb_rating      8.4       9.3
# budget         250.0   70000.0
# revenue       2000.0  100000.0

# %%
df_b=df[df.industry=="Bollywood"]
df_h=df[df.industry=="Hollywood"]

# %%
df_h
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# 12                                The Godfather  Hollywood          1972
# ...

# %%
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
df.value_counts(['industry'])
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %%
df.language.unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df_new=df[["title","imdb_rating","industry"]]
df_new.head(4)
# Out:
#                                          title  imdb_rating   industry
# 0                              Pather Panchali          8.3  Bollywood
# 1  Doctor Strange in the Multiverse of Madness          7.0  Hollywood
# 2                        Thor: The Dark World           6.8  Hollywood
# 3                              Thor: Ragnarok           7.9  Hollywood

# %%
df[(df.release_year>=2000) & (df.release_year<=2010)]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 7   The Pursuit of Happyness  Hollywood          2006          8.0
# 8                  Gladiator  Hollywood          2000          8.5
# 11                    Avatar  Hollywood          2009          7.8
# 13           The Dark Knight  Hollywood          2008          9.0
# 22                  3 Idiots  Bollywood          2009          8.4
# 23  Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 25          Taare Zameen Par  Bollywood          2007          8.3
# 26       Munna Bhai M.B.B.S.  Bollywood          2003          8.1
#
#                       studio  budget  revenue      unit currency language
# 7          Columbia Pictures    55.0    307.1  Millions      USD  English
# 8       Universal Pictures     103.0    460.5  Millions      USD  English
# 11          20th Century Fox   237.0   2847.0  Millions      USD  English
# ...

# %%
df[df.studio=='Marvel Studios']
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
df[(df.imdb_rating==df.imdb_rating.max()) | (df.imdb_rating==df.imdb_rating.min())]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 31                    Race 3  Bollywood          2018          1.9
#
#                        studio  budget  revenue      unit currency language
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 31          Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %%
df["age"]=df['release_year'].apply(lambda x:2024-x )
df.head(4)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
#
#   currency language  age
# 0      INR  Bengali   69
# 1      USD  English    2
# 2      USD  English   11
# 3      USD  English    7

# %%
df["profit"]=df.apply(lambda x: x['revenue']-x['budget'], axis=1)
df.head(4)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
#
#   currency language  age   profit
# 0      INR  Bengali   69  30000.0
# 1      USD  English    2    754.8
# 2      USD  English   11    479.8
# 3      USD  English    7    674.0

# %%
df.set_index("title", inplace=True)
df.head(4)
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
# Thor: Ragnarok                                       7.9
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# Doctor Strange in the Multiverse of Madness             Marvel Studios
# Thor: The Dark World                                    Marvel Studios
# ...

# %%
df.loc["Pather Panchali"]
# Out:
# industry                        Bollywood
# release_year                         1955
# imdb_rating                           8.3
# studio          Government of West Bengal
# budget                            70000.0
# revenue                          100000.0
# unit                            Thousands
# currency                              INR
# language                          Bengali
# age                                    69
# profit                            30000.0
# Name: Pather Panchali, dtype: object

# %%
df.loc[["Pather Panchali","Doctor Strange in the Multiverse of Madness"]]
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# Doctor Strange in the Multiverse of Madness             Marvel Studios
#
#                                               budget   revenue       unit  \
# title
# Pather Panchali                              70000.0  100000.0  Thousands
# Doctor Strange in the Multiverse of Madness    200.0     954.8   Millions
#
#                                             currency language  age   profit
# title
# ...

# %%
df.iloc[2:6]
# Out:
#                            industry  release_year  imdb_rating  \
# title
# Thor: The Dark World      Hollywood          2013          6.8
# Thor: Ragnarok            Hollywood          2017          7.9
# Thor: Love and Thunder    Hollywood          2022          6.8
# The Shawshank Redemption  Hollywood          1994          9.3
#
#                                              studio  budget  revenue  \
# title
# Thor: The Dark World                 Marvel Studios   165.0    644.8
# Thor: Ragnarok                       Marvel Studios   180.0    854.0
# Thor: Love and Thunder               Marvel Studios   250.0    670.0
# The Shawshank Redemption  Castle Rock Entertainment    25.0     73.3
#
#                               unit currency language  age  profit
# title
# Thor: The Dark World      Millions      USD  English   11   479.8
# Thor: Ragnarok            Millions      USD  English    7   674.0
# Thor: Love and Thunder    Millions      USD  English    2   420.0
# ...

# %%
df.reset_index(inplace=True)
df.head(4)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
#
#   currency language  age   profit
# 0      INR  Bengali   69  30000.0
# 1      USD  English    2    754.8
# 2      USD  English   11    479.8
# 3      USD  English    7    674.0

# %%
df=pd.read_csv("movies.csv")
df.head
df_new=df[["title","release_year","imdb_rating","industry"]]
df_new
# Out:
#                                           title  release_year  imdb_rating  \
# 0                               Pather Panchali          1955          8.3
# 1   Doctor Strange in the Multiverse of Madness          2022          7.0
# 2                         Thor: The Dark World           2013          6.8
# 3                               Thor: Ragnarok           2017          7.9
# 4                       Thor: Love and Thunder           2022          6.8
# 5                      The Shawshank Redemption          1994          9.3
# 6                                  Interstellar          2014          8.6
# 7                      The Pursuit of Happyness          2006          8.0
# 8                                     Gladiator          2000          8.5
# 9                                       Titanic          1997          7.9
# 10                        It's a Wonderful Life          1946          8.6
# ...

# %%
df_new=df[df.industry=="Bollywood"]
df_new
# Out:
#                           title   industry  release_year  imdb_rating  \
# 0               Pather Panchali  Bollywood          1955          8.3
# 21  Dilwale Dulhania Le Jayenge  Bollywood          1995          8.0
# 22                     3 Idiots  Bollywood          2009          8.4
# 23     Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 24             Bajirao Mastani   Bollywood          2015          7.2
# 25             Taare Zameen Par  Bollywood          2007          8.3
# 26          Munna Bhai M.B.B.S.  Bollywood          2003          8.1
# 27                           PK  Bollywood          2014          8.1
# 28                        Sanju  Bollywood          2018          NaN
# 29            The Kashmir Files  Bollywood          2022          8.3
# 30            Bajrangi Bhaijaan  Bollywood          2015          8.1
# 31                       Race 3  Bollywood          2018          1.9
# ...

# %%
df1=df_new[["title","release_year","imdb_rating","industry"]]
df1
# Out:
#                           title  release_year  imdb_rating   industry
# 0               Pather Panchali          1955          8.3  Bollywood
# 21  Dilwale Dulhania Le Jayenge          1995          8.0  Bollywood
# 22                     3 Idiots          2009          8.4  Bollywood
# 23     Kabhi Khushi Kabhie Gham          2001          7.4  Bollywood
# 24             Bajirao Mastani           2015          7.2  Bollywood
# 25             Taare Zameen Par          2007          8.3  Bollywood
# 26          Munna Bhai M.B.B.S.          2003          8.1  Bollywood
# 27                           PK          2014          8.1  Bollywood
# 28                        Sanju          2018          NaN  Bollywood
# 29            The Kashmir Files          2022          8.3  Bollywood
# 30            Bajrangi Bhaijaan          2015          8.1  Bollywood
# 31                       Race 3          2018          1.9  Bollywood
# ...

# %%
df2=pd.read_csv("Book2a.csv")
df2
# Out:
#       year  rating  actionmv  animemv
# 0  y1 2022    12.5       8.0      9.2
# 1  y2 2022    11.0       7.5      8.5
# 2  y3 2022    13.2       9.0      7.5
# 3  y4 2022    16.4      11.0      7.6
# 4  y1 2023    13.8       9.5      6.8
# 5  y2 2023    14.0       8.0      6.0

# %% [markdown]
# 2.Line Chart

# %%
df2.plot(kind='line',subplots=True)
plt.figure(figsize=(12,4))
plt.show()

# %% [markdown]
# 3.Pie Chart

# %%
piech=df2[["rating","actionmv","animemv"]].sum()
piech
# Out:
# rating      80.9
# actionmv    53.0
# animemv     45.6
# dtype: float64

# %%
plt.pie(piech, labels=piech.index, autopct="%1.1f%%",explode=(0.1,0,0),shadow=True, startangle=140)
plt.show()

# %% [markdown]
# 4.Bar Chart

# %%
df2.plot(kind="bar",x="year")
plt.xticks(rotation=45)
plt.show()

# %%
yr=df2.set_index("year")
yr
# Out:
#          rating  actionmv  animemv
# year
# y1 2022    12.5       8.0      9.2
# y2 2022    11.0       7.5      8.5
# y3 2022    13.2       9.0      7.5
# y4 2022    16.4      11.0      7.6
# y1 2023    13.8       9.5      6.8
# y2 2023    14.0       8.0      6.0

# %% [markdown]
# 5.Box plot

# %%
yr.boxplot()
# Out:
# <Axes: >

# %%
yr.loc["y1 2022"]
# Out:
# rating      12.5
# actionmv     8.0
# animemv      9.2
# Name: y1 2022, dtype: float64

# %%
hstogrm=pd.read_csv("histogram.csv")
hstogrm.head(3)
# Out:
#   Directors  success %
# 0     Virat         98
# 1   Anushka         67
# 2     Siraj         68

# %% [markdown]
# 6.Histogram

# %%
sns.histplot(hstogrm["success %"], kde=True)
plt.show()

# %%
sctplt=pd.read_csv("sctr_plt.csv")
sctplt
# Out:
#       Country  mv_Profit %  Profitamt
# 0       India         11.7     175000
# 1         USA         29.0     420000
# 2    Pakistan         11.4      44500
# 3  Bangladesh         17.8     115000
# 4          UK         23.0     212000
# 5     Germany         33.3     200000
# 6   Australia         25.6     230000
# 7      Canada         20.0     220000

# %% [markdown]
# 7.Scatter Plot

# %%
sns.scatterplot(data=sctplt,x="mv_Profit %",y="Profitamt")
plt.show()

# %%
ts=pd.Series(np.random.randn(500), index=pd.date_range('1/2/2020',periods=500))
ts=ts.cumsum()
ts.plot()
# Out:
# <Axes: >
